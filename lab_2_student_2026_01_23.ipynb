# %% [markdown]
# <a href="https://colab.research.google.com/github/annapetrbok/ee467wi2026/blob/main/lab_2_student_2026_01_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EE 467 Lab 2: Breaking CAPTCHAs with Tensorflow / Keras
# In lab 2, we are going to work on automatically breaking CAPTCHAs with deep learning! Originally, CAPTCHA stands for "Completely Automated Public Turing test to tell Computers and Humans Apart", and traditional CAPCTHAs serve as a great tool to stop spam bots and malicious crawlers. Today, as we have made huge progress in computer vision and deep learning, these CAPCTHAs are no longer unbreakable by computers. Now let's prove the correctness of the claim by ourselves!
#
# As usual, please check if the helper library, `lab_2_helpers.py` and the extracted dataset directory, `captcha-images` exist under the same directory. Then, please install all libraries used for this lab:

# %%
# %pip install matplotlib scikit-learn "opencv-python>4" imutils

# Install Tensorflow with CPU support only, or ...
# %pip install "tensorflow>2"
# Install Tensorflow with GPU support:
#%pip install tensorflow-gpu>2

# %% [markdown]
# Next, we import all tools needed before starting:

# %%
import os, pickle, glob, math
from pprint import pprint

import cv2
import numpy as np
import imutils
from imutils import paths
from tensorflow.keras import Sequential, layers
from matplotlib import pyplot as plt
from matplotlib.gridspec import GridSpec
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

from google.colab import files
files.upload()

from lab_2_helpers import *

# %% [markdown]
# # Preprocessing
# ## Ground Truth Characters Extraction
# As usual, we will start pre-processing stage by loading CAPTCHA images into the memory:

# %%
# !tar -xJf captcha-images.tar.xz

# %%
# Dataset images folder
CAPTCHA_IMAGE_FOLDER = "./captcha-images"

# List of all the captcha images we need to process
captcha_image_paths = list(paths.list_images(CAPTCHA_IMAGE_FOLDER))
# Review image paths
pprint(captcha_image_paths[:10])

# %% [markdown]
# Note that for each image, its file name (without extension) happens to be its corresponding CAPTCHA text. Thus, we extract file names for all CAPTCHA images and save them as labels for future use:

# %%
def extract_captcha_text(image_path):
    """ Extract correct CAPTCHA texts from file name of images. """
    # Extract file name of image from its path
    # e.g. "./captcha-images/2A2X.png" -> "2A2X.png"
    image_file_name = os.path.basename(image_path)
    # Extract base name of image, omitting file extension
    # e.g. "2A2X.png" -> "2A2X"
    return os.path.splitext(image_file_name)[0]

captcha_texts = [extract_captcha_text(image_path) for image_path in captcha_image_paths]
# Review extraction results
pprint(captcha_texts[:10])

# %% [markdown]
# ## Loading and Transforming Images
# For the feature extraction stage, we are going to extract individual characters from these CAPTCHAs. This is done by looking for contours (bounding boxes) around characters, then cropping the CAPTCHAs such as only the contour areas are preserved. We begin feature extraction by loading and transforming images:

# %%
import cv2

def load_transform_image(image_path):
    """ Load and transform image into grayscale. """
    ## [ TODO ]
    # 1) Load image with OpenCV
    image = cv2.imread(image_path)

    # 2) Convert image to grayscale
    image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # 3) Add extra padding (8px) around the image
    image_padded = cv2.copyMakeBorder(image_gray, 8, 8, 8, 8, cv2.BORDER_REPLICATE)

    return image_padded

captcha_images = [load_transform_image(image_path) for image_path in captcha_image_paths]
# Review loaded CAPTCHAs
print_images(
    captcha_images[:10], n_rows=2, texts=captcha_texts[:10]
)

# %% [markdown]
# Next, we will split our dataset into train-validation set and test set. The former set will be used for training and validation in deep character classification model, while the latter will be used for testing our CAPTCHA recognition pipline end-to-end:

# %%
# Train-validation-test split seed
TVT_SPLIT_SEED = 31528476

# Perform split on CAPTCHA images as well as labels
captcha_images_tv, captcha_images_test, captcha_texts_tv, captcha_texts_test = train_test_split(
    captcha_images, captcha_texts, test_size=0.2, random_state=TVT_SPLIT_SEED
)

print("Train-validation:", len(captcha_texts_tv))
print("Test:", len(captcha_texts_test))

# %% [markdown]
# ## Bounding Box Extraction
# It's now time to perform the most important feature extraction step: finding contours and extracting characters. Contours can be explained simply as a curve joining all the continuous points (along the boundary), having same color or intensity. It is useful for shape analysis and object detection and recognition. For our task however, we are **more interested in the bounding boxes around characters**, since these are the part of images we will be used for character classification:
#
# ![char-contours.png](attachment:char-contours.png)
#
# Here are the steps we are going to perform:
#
# * Find contours around characters in CAPTCHAs.
# * Get the position and size for each corresponding bounding box.
# * If a bounding box is too wide (width-to-height ratio larger than 1.25), chances are that we have bounded two letters in a single bounding box. In this case, split the bounding box vertically from the center into two.
# * Store all bounding boxes for the CAPTCHA.
# * If there aren't 4 bounding boxes for the CAPTCHA, ignore it since our character extraction process must have run into problems in this case.
# * Sort the bounding boxes by their X coordinates, so that they match the order corresponding letters occur.
# * For each bounding box, extract corresponding region of the image, and store it as an instance of corresponding character at `${CHAR_IMAGE_FOLDER}/{letter}/{count}.png`.
#
# After these steps, we have transformed CAPTCHA images into images of single character. This simplifies our task since now our model only needs to deal with classification (from character image to character itself) rather than also dealing with detection (finding and extracting charatcers).

# %%
# Character images folder template
CHAR_IMAGE_FOLDER = f"./char-images-{TVT_SPLIT_SEED}"

def extract_chars(image):
    """ Find contours and extract characters inside each CAPTCHA. """
    # Threshold image and convert it to black-white
    image_bw = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY_INV | cv2.THRESH_OTSU)[1]
    # Find contours (continuous blobs of pixels) the image
    contours = cv2.findContours(image_bw, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)[0]

    char_regions = []
    # Loop through each contour
    for contour in contours:
        # Get the rectangle that contains the contour
        x, y, w, h = cv2.boundingRect(contour)

        # Compare the width and height of the bounding box,
        # detect if there are letters conjoined into one chunk
        if w / h > 1.25:
            # Bounding box is too wide for a single character
            # Split it in half into two letter regions
            half_width = int(w / 2)
            char_regions.append((x, y, half_width, h))
            char_regions.append((x + half_width, y, half_width, h))
        else:
            # Only a single letter in contour
            char_regions.append((x, y, w, h))

    # Ignore image if less or more than 4 regions detected
    if len(char_regions)!=4:
        return None
    # Sort regions by their X coordinates
    char_regions.sort(key=lambda x: x[0])

    # Character images
    char_images = []
    # Save each character as a single image
    for x, y, w, h in char_regions:
        # Extract character from image with 2px margin
        char_image = image[y - 2:y + h + 2, x - 2:x + w + 2]
        # Save character images
        char_images.append(char_image)

    # Return character images
    return char_images

def save_chars(char_images, captcha_text, save_dir, char_counts):
    """ Save character images to directory. """
    for char_image, char in zip(char_images, captcha_text):
        # Get the folder to save the image in
        save_path = os.path.join(save_dir, char)
        os.makedirs(save_path, exist_ok=True)

        # Write letter image to file
        char_count = char_counts.get(char, 1)
        char_image_path = os.path.join(save_path, f"{char_count}.png")
        cv2.imwrite(char_image_path, char_image)

        # Update count
        char_counts[char] = char_count+1

# Force character extraction even if results are already available
FORCE_EXTRACT_CHAR = False

char_counts = {}
# Extract and save images for characters
if FORCE_EXTRACT_CHAR or not os.path.exists(CHAR_IMAGE_FOLDER):
    for captcha_image, captcha_text in zip(captcha_images_tv, captcha_texts_tv):
        # Extract character images
        char_images = extract_chars(captcha_image)
        # Skip if extraction failed
        if char_images is None:
            continue
        # Save character images
        save_chars(char_images, captcha_text, CHAR_IMAGE_FOLDER, char_counts)

# %% [markdown]
# ## Label Encoding
# During the training stage, we are going to load character images from previous stages as features and generate corresponding labels from their path. We will then rescale features, one-hot encode labels (occurred characters) and save labels to an external file.

# %%
# Path of occurred characters (labels)
LABELS_PATH = "./labels.pkl"

def make_feature(image):
    """ Process character image and turn it into feature. """
    # Resize letter to 20*20
    image_resized = resize_to_fit(image, 20, 20)
    # Add extra dimension as the only channel
    feature = image_resized[..., None]

    return feature

def make_feature_label(image_path):
    """ Load character image and make feature-label pair from image path. """
    # Load image and make feature
    feature = make_feature(cv2.imread(image_path, cv2.COLOR_BGR2GRAY))
    # Extract label based on the directory the image is in
    label = image_path.split(os.path.sep)[-2]

    return feature, label

# Make features and labels from character image paths
features_tv, labels_tv = unzip((
    make_feature_label(image_path) for image_path in paths.list_images(CHAR_IMAGE_FOLDER)
))

# Scale raw pixel values into range [0, 1]
features_tv = np.array(features_tv, dtype="float")/255
# Convert labels into one-hot encodings
lb = LabelBinarizer()
labels_one_hot_tv = lb.fit_transform(labels_tv)
# Number of classes
n_classes = len(lb.classes_)

# Further split the training data into training and validation set
X_train, X_vali, y_train, y_vali = train_test_split(
    features_tv, labels_one_hot_tv, test_size=0.25, random_state=955996
)
# Save mapping from labels to one-hot encoding
with open(LABELS_PATH, "wb") as f:
    pickle.dump(lb, f)

# %% [markdown]
# # Training
# Next, we build a Convolutional Neural Network (CNN) as our classification model with Tensorflow / Keras. The structure of the neural network is shown below:
#
# ![conv-net-structure.png](attachment:conv-net-structure.png)
#
# After building the neural network, we train it and save weights.

# %%
# Batch size
BATCH_SIZE = 32
# Number of epochs
N_EPOCHS = 10

# Path of model weights file
MODEL_WEIGHTS_PATH = "./captcha-model.weights.h5"
# Force training even if weights are already available
FORCE_TRAINING = True

# Build a feed-forward neural network
model = Sequential()

## [ TODO ]
# Implement the neural network shown above

# First convolution block: (*, 20, 20, 1) -Conv2D+ReLU-> (*, 20, 20, 20) -MaxPooling2D-> (*, 10, 10, 20)
# (Remember to include input shape for the first layer!)

# 1) Convolution layer: 20 channels, 5*5 kernel, ReLU activation, padded to maintain same shape
model.add(layers.Conv2D(20, (5, 5), padding="same", activation="relu", input_shape=(20, 20, 1)))
# 2) Max pooling layer: 2*2 kernel
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

# Second convolution block: (*, 10, 10, 20) -Conv2D+ReLU-> (*, 10, 10, 50) -MaxPooling2D-> (*, 5, 5, 50)
# Convolution layer: same as above, but use 50 channels
model.add(layers.Conv2D(50, (5, 5), padding="same", activation="relu"))
model.add(layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

# Flatten layer reshape features to 1D: (*, 5, 5, 50) -Flatten-> (*, 1250)
model.add(layers.Flatten())

# First fully-connected (linear) layer: (*, 1250) -FC+ReLU -> (*, 500)
model.add(layers.Dense(500, activation="relu"))
# Last fully-connected (linear) layer: (*, 500) -FC+Softmax-> (*, n_classes)
# Softmax outputs a categorical distribution representing probability for each character
model.add(layers.Dense(n_classes, activation="softmax"))

# Build classification model with Adam optimizer and cross entropy loss
model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

if FORCE_TRAINING or not os.path.exists(MODEL_WEIGHTS_PATH):
    # Train the neural network model
    model.fit(
        X_train, y_train, validation_data=(X_vali, y_vali),
        batch_size=BATCH_SIZE, epochs=N_EPOCHS, verbose=1
    )
    # Save model weights to disk
    model.save_weights(MODEL_WEIGHTS_PATH)
else:
    model.load_weights(MODEL_WEIGHTS_PATH)

# Show model summary
print(model.summary())

# %% [markdown]
# # Evaluation
# During the training part, we have validated the performance of our neural network model on images of single characters. Now it's time to test and evaluate CAPTCHAs from the beginning to the end. First, we will need to build the pipeline for CAPTCHA character prediction:

# %%
# Load labels from file (so we can translate model predictions to actual letters)
with open(LABELS_PATH, "rb") as f:
    lb = pickle.load(f)

# Test our pipeline (and model) with the test set.
# However, you'd want to replace this with some random CAPTCHAs in the real world.

# Dummy character images
DUMMY_CHAR_IMAGES = np.zeros((4, 20, 20, 1))

# Indices of CAPTCHAs on which extractions failed
extract_failed_indices = []
# Extracted character images
char_images_test = []

# Extract character images and make features
for i, captcha_image in enumerate(captcha_images_test):
    # Extract character images
    char_images = extract_chars(captcha_image)

    if char_images:
        char_images_test.extend(char_images)
    # Use dummy character images as placeholder if extraction failed
    else:
        extract_failed_indices.append(i)
        char_images_test.extend(DUMMY_CHAR_IMAGES)

# Make features for character images
features_test = [make_feature(char_image) for char_image in char_images_test]
# Scale raw pixel values into range [0, 1]
features_test = np.array(features_test, dtype="float")/255

# Make features for character images
features_test = [make_feature(char_image) for char_image in char_images_test]
# Scale raw pixel values into range [0, 1]
features_test = np.array(features_test, dtype="float")/255
# Predict labels with neural network
preds_test = model.predict(features_test)
# Convert one-hot encoded characters back
preds_test = lb.inverse_transform(preds_test)

# Group all 4 characters for the same CAPTCHA
preds_test = ["".join(chars) for chars in group_every(preds_test, 4)]
# Update result for CAPTCHAs on which extractions failed
for i in extract_failed_indices:
    preds_test[i] = "-"

# %% [markdown]
# Now, we can compute the accuracy of our pipeline, as well as taking a look at correct and incorrect CAPTCHA text predictions:

# %%
# Number of CAPTCHAs to display
N_DISPLAY_SAMPLES = 10

# Number of test CAPTCHAs
n_test = len(captcha_texts_test)
# Number of correct predictions
n_correct = 0

# Indices of correct predictions
correct_indices = []
# Indices of incorrect predictions
incorrect_indices = []

for i, (pred_text, actual_text) in enumerate(zip(preds_test, captcha_texts_test)):
    if pred_text==actual_text:
        # 1) Update number of correct predictions
        n_correct += 1
        # 2) Collect index of correct prediction
        if len(correct_indices)<N_DISPLAY_SAMPLES:
            correct_indices.append(i)
    else:
        # 3) Collect index of incorrect prediction
        if len(incorrect_indices)<N_DISPLAY_SAMPLES:
            incorrect_indices.append(i)

# Show number of total / correct predictions and accuracy
print("# of test CAPTCHAs:", n_test)
print("# correctly recognized:", n_correct)
print("Accuracy:", n_correct/n_test, "\n")

# Show all correct predictions
print_images(
    [captcha_images_test[i] for i in correct_indices],
    texts=[f"Correct: {captcha_texts_test[i]}" for i in correct_indices],
    n_rows=2
)

# Show all incorrect predictions
print_images(
    [captcha_images_test[i] for i in incorrect_indices],
    texts=[
        f"Prediction: {preds_test[i]}\nActual: {captcha_texts_test[i]}" \
        for i in incorrect_indices
    ],
    n_rows=2,
    fig_size=(20, 6),
    text_center=(0.5, -0.25)
)

# %%
# %cd /content/ee467wi2026
# !ls -la
from lab_2_helpers import *

# %%
# %cd /content/ee467wi2026
# !ls ee467wi2026

# %%
# %cd /content/ee467wi2026
# !git add .
# !git commit -m "Clear outputs and add lab files"
# !git push
# Out:
# /content/ee467wi2026
# warning: adding embedded git repository: ee467wi2026
# hint: You've added another git repository inside your current repository.
# hint: Clones of the outer repository will not contain the contents of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a submodule, use:
# hint:
# hint: 	git submodule add <url> ee467wi2026
# hint:
# hint: If you added this path by mistake, you can remove it from the
# hint: index with:
# hint:
# hint: 	git rm --cached ee467wi2026
# hint:
# hint: See "git help submodule" for more information.
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@03d374ffdc76.(none)')
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# %cd /content/ee467wi2026
# !git config user.name "annapetrbok"
# !git config user.email "apetrbok@uw.edu"

# !git status
# !git add .
# !git commit -m "Clean repo structure and add lab assets"
# Out:
# Streaming output truncated to the last 5000 lines.
# 	new file:   char-images-31528476/V/46.png
# 	new file:   char-images-31528476/V/47.png
# 	new file:   char-images-31528476/V/48.png
# 	new file:   char-images-31528476/V/49.png
# 	new file:   char-images-31528476/V/5.png
# 	new file:   char-images-31528476/V/50.png
# 	new file:   char-images-31528476/V/51.png
# 	new file:   char-images-31528476/V/52.png
# 	new file:   char-images-31528476/V/53.png
# 	new file:   char-images-31528476/V/54.png
# 	new file:   char-images-31528476/V/55.png
# 	new file:   char-images-31528476/V/56.png
# 	new file:   char-images-31528476/V/57.png
# 	new file:   char-images-31528476/V/58.png
# 	new file:   char-images-31528476/V/59.png
# 	new file:   char-images-31528476/V/6.png
# 	new file:   char-images-31528476/V/60.png
# 	new file:   char-images-31528476/V/61.png
# 	new file:   char-images-31528476/V/62.png
# 	new file:   char-images-31528476/V/63.png
# 	new file:   char-images-31528476/V/64.png
# 	new file:   char-images-31528476/V/65.png
# 	new file:   char-images-31528476/V/66.png
# 	new file:   char-images-31528476/V/67.png
# 	new file:   char-images-31528476/V/68.png
# 	new file:   char-images-31528476/V/69.png
# 	new file:   char-images-31528476/V/7.png
# 	new file:   char-images-31528476/V/70.png
# 	new file:   char-images-31528476/V/71.png
# 	new file:   char-images-31528476/V/72.png
# 	new file:   char-images-31528476/V/73.png
# 	new file:   char-images-31528476/V/74.png
# 	new file:   char-images-31528476/V/75.png
# 	new file:   char-images-31528476/V/76.png
#   adding: ee467wi2026/.git/objects/c8/ (stored 0%)
#   adding: ee467wi2026/.git/objects/c8/50c72d808b3f97b2f4a4fa274ebc7d1d10db3f (stored 0%)
#   adding: ee467wi2026/.git/objects/c8/4727a607f9d228b126eda609d6108f8c2b35ef (stored 0%)
#   adding: ee467wi2026/.git/objects/c8/d2e3fa93e79c6b812a230e7eec581ff8de1e7f (stored 0%)
#   adding: ee467wi2026/.git/objects/c8/3feef1f95be65fc4b02e10c3b291571fb96c0b (stored 0%)
#   adding: ee467wi2026/.git/objects/c8/b60fb2a42c8d7b6b61fb6367ad1737b2fd8371 (stored 0%)
#   adding: ee467wi2026/.git/objects/c8/0020396ae00f0f36b9fca8e036458be0301944 (stored 0%)
#   adding: ee467wi2026/.git/objects/c8/8e622a1e4039d1032607dce1380cb0b7150e7b (stored 0%)
#   adding: ee467wi2026/.git/objects/c8/901582a1ba9f43c31838fa98da6010185287a6 (stored 0%)
#   adding: ee467wi2026/.git/objects/c8/da83fd04b8d592426de08330ebc61388d9f58b (stored 0%)
#   adding: ee467wi2026/.git/objects/01/ (stored 0%)
#   adding: ee467wi2026/.git/objects/01/9cef3a65136192e8fb4cfe1d8a9c31f2d2ae49 (stored 0%)
#   adding: ee467wi2026/.git/objects/01/2587e6095243daf8f1baad16d12268e3cdd7de (stored 0%)
#   adding: ee467wi2026/.git/objects/01/ea4d6f223d0b8fce294e2e736ef3e67d9b1e13 (stored 0%)
#   adding: ee467wi2026/.git/objects/01/9efccd05eaffcedd9416beae101663f4de0c85 (stored 0%)
#   adding: ee467wi2026/.git/objects/01/a174ba1b6a374a6f9e8b9b2987776f4b3bfa32 (stored 0%)
#   adding: ee467wi2026/.git/objects/01/7e56ae8bb8e54e84711ff7bd09fd7c719d7095 (stored 0%)
#   adding: ee467wi2026/.git/objects/01/0060546830e81d54fdb632d18ae11daa20be55 (stored 0%)
#   adding: ee467wi2026/.git/objects/01/45a589053471ef9a47464596e23271d63d09c9 (stored 0%)
#   adding: ee467wi2026/.git/objects/01/56d863dec4c911e59047d5660e173cdf19aeb8 (stored 0%)
#   adding: ee467wi2026/.git/objects/01/7936b71310b296a505c376bc809252427ddde7 (stored 0%)
#   adding: ee467wi2026/.git/objects/01/21a191e925fe8478eceb35087f5dab695e0ebf (stored 0%)
#   adding: ee467wi2026/.git/objects/01/64b7bd7c9af37190498b517b912122aa47b13e (stored 0%)
#   adding: ee467wi2026/.git/objects/01/662f73ad49825598333ccecd5a90750192850f (stored 0%)
#   adding: ee467wi2026/.git/objects/fd/ (stored 0%)
#   adding: ee467wi2026/.git/objects/fd/9a03ad9c70af8c6d6a22fff08146fef321b3e5 (stored 0%)
#   adding: ee467wi2026/.git/objects/fd/2942bac7a1e0d0e3b3d5faddf1bb7465a04a87 (stored 0%)
#   adding: ee467wi2026/.git/objects/fd/4825ada2fc0fd14c1797636fba4b4026ef621e (stored 0%)
#   adding: ee467wi2026/.git/objects/fd/dff1b703945a6d2a01f75d7a28373ecfce03e0 (stored 0%)
stored 0%)
#   adding: ee467wi2026/.git/objects/9f/db6e8a1abaf9203952bfc100350ca458e10d79 (stored 0%)
#   adding: ee467wi2026/.git/objects/9f/035d29e98d42275e60633904feff7a26909d87 (stored 0%)
#   adding: ee467wi2026/.git/objects/9f/eec61ce106325ed578c4828e0015a98e0f516a (stored 0%)
#   adding: ee467wi2026/.git/objects/9f/761b4393c37343a16aa71df703c89f8ad16bef (stored 0%)
#   adding: ee467wi2026/.git/objects/9f/d8e576877ba305c434d4aaa14cb6d2eeb4b2cd (stored 0%)
#   adding: ee467wi2026/.git/objects/9f/d60aa45cc518bbcc3ba653c72d5b2aa9429197 (stored 0%)
#   adding: ee467wi2026/.git/objects/d1/ (stored 0%)
#   adding: ee467wi2026/.git/objects/d1/1f177c1dd18929c4cb37d4e9743562a67461eb (stored 0%)
#   adding: ee467wi2026/.git/objects/d1/f4195477396b29c895b16d2a2900d76b605182 (stored 0%)
#   adding: ee467wi2026/.git/objects/d1/4b1cbc5cf60dc619a21c1d05354edde5206ddb (stored 0%)
#   adding: ee467wi2026/.git/objects/d1/dc69485fc751b05af539f83403f21b2f46a3da (stored 0%)
#   adding: ee467wi2026/.git/objects/d1/96e253db979dca4a1f23b69cd420c740a754ec (stored 0%)
#   adding: ee467wi2026/.git/objects/d1/df759fd166d5d21de8512fd3624f12e700287e (stored 0%)
#   adding: ee467wi2026/.git/objects/d1/23c3fdeba0911cb6edfd06e1ff4be73573993c (stored 0%)
#   adding: ee467wi2026/.git/objects/d1/8ee3765987c8f856d521b5a962f8ce36d31810 (stored 0%)
#   adding: ee467wi2026/.git/objects/d1/0d04ed983a5d367399a82cbf262619e0d43b7b (stored 0%)
#   adding: ee467wi2026/.git/objects/d1/8b8c2df101ec0d4c1335731566df06b83da457 (stored 0%)
#   adding: ee467wi2026/.git/objects/d1/0e3627a0682716dba68189be59f485580882c5 (stored 0%)
#   adding: ee467wi2026/.git/objects/46/ (stored 0%)
#   adding: ee467wi2026/.git/objects/46/612c71e02857dfd601bc93ae39e5ec02efea67 (stored 0%)
#   adding: ee467wi2026/.git/objects/46/da83208059483078d4431bc2f1b7bcf48a26f8 (stored 0%)
#   adding: ee467wi2026/.git/objects/46/4ee9f7b6b421e12098b17a2d02bb6cd3ef7ef4 (stored 0%)
#   adding: ee467wi2026/.git/objects/46/08ebe537dd49cb73935a7b7621c3867ccf5eeb (stored 0%)
#   adding: ee467wi2026/.git/objects/46/2afc8c453a23475cb5f0ac5508be67b458156b (stored 0%)
#   adding: ee467wi2026/.git/objects/46/79108b9f72ebf45b02c30ba90d701fab5c14eb (stored 0%)
#   adding: ee467wi2026/.git/objects/46/4b412e1b55303dac454885dad21f9e795dee61 (stored 0%)
#   adding: ee467wi2026/.git/objects/46/80621591d71cf26cbcbcd38b08eec158bec6ff (stored 0%)
#   adding: ee467wi2026/.git/objects/46/1d03d748132f3d983aab5d09393286f86ae010 (stored 0%)
#   adding: ee467wi2026/.git/objects/46/7f65322704e470939abebde120237029f5d22e (stored 0%)
#   adding: ee467wi2026/.git/objects/46/fff90547862698f5671a17d32d54b143325bed (stored 0%)
#   adding: ee467wi2026/.git/objects/68/ (stored 0%)
#   adding: ee467wi2026/.git/objects/68/7d9382130c541456f6365c726fcf019c3301a7 (stored 0%)
#   adding: ee467wi2026/.git/objects/68/949712dbecc3a3078ffc2f168befd48c42dd47 (stored 0%)
#   adding: ee467wi2026/.git/objects/68/e8054c960000e4267cec713f7a414aae805dfb (stored 0%)
#   adding: ee467wi2026/.git/objects/68/d8832478054a753f836e21e3e5ff8bfed71566 (stored 0%)
#   adding: ee467wi2026/.git/objects/68/05b8df64cda778e7ea8d449074aa08094ae42d (stored 0%)
#   adding: ee467wi2026/.git/objects/68/9be1b7c5fbf82f3d53ca05f638c89c84a1a89e (stored 0%)
#   adding: ee467wi2026/.git/objects/68/0db7629e2e6ed405643fd88ee7a9fecfc0e34e (stored 0%)
#   adding: ee467wi2026/.git/objects/68/68f420bb906067882f65586710b503d255ccb2 (stored 0%)
#   adding: ee467wi2026/.git/objects/68/1e12507a05ecf8e269f75c8eedbf2adfbbeb4f (stored 0%)
#   adding: ee467wi2026/.git/objects/68/429fb0a4c781c5e6553d53b1cce7154f4447e8 (stored 0%)
#   adding: ee467wi2026/.git/objects/68/b993891aff4aaf8a6d1f615b889922e5c529f4 (stored 0%)
#   adding: ee467wi2026/.git/objects/68/4e847cf7f55cc66c5615cc841c4f5e469795d3 (stored 0%)
#   adding: ee467wi2026/.git/objects/68/58b3145ca6c8c47bd64032cdad3309b23ba2a1 (stored 0%)
#   adding: ee467wi2026/.git/objects/68/fe9ae0f9e37b2d22f3cacaed3e9ebbb2d744c0 (stored 0%)
#   adding: ee467wi2026/.git/objects/74/ (stored 0%)
#   adding: ee467wi2026/.git/objects/74/98aecd476784fe1a53ecba6c26a9c676cfd5f4 (stored 0%)
#   adding: ee467wi2026/.git/objects/74/94f91d1633be8b1816494a3c790239fa92f02a (stored 0%)
#   adding: ee467wi2026/.git/objects/74/48f010f689f73b548b9476846f778b9f4fd501 (stored 0%)
#   adding: ee467wi2026/.git/objects/74/c459a6493dcf8e5bd89b15b94107456304e481 (stored 0%)
#   adding: ee467wi2026/.git/objects/74/c8b550519a559f39f9b479c6992f1f5f2a08cb (stored 0%)
#   adding: ee467wi2026/.git/objects/74/5c5291eac0bb8c3becd7feadc0e39ad7e0400f (stored 0%)
#   adding: ee467wi2026/.git/objects/74/8eb1e02bbe2aa531ddeed36f68fe0b8dd988f5 (stored 0%)
#   adding: ee467wi2026/.git/objects/74/6ec6ad09f67afbc176f29d8fdb2c0432a862b8 (stored 0%)
#   adding: ee467wi2026/.git/objects/74/7ad10146c516110cfafead2526811731584f92 (stored 0%)
#   adding: ee467wi2026/.git/objects/74/1d05cae8edfc5db1520c1550fb5bfc724ba7e6 (stored 0%)
#   adding: ee467wi2026/.git/objects/74/8ca267be360a96dfc429dfa6f459389507ccfb (stored 0%)
#   adding: ee467wi2026/.git/objects/74/3eb51e50cf9a2ca8f1d677a22140a6c0448d49 (stored 0%)
#   adding: ee467wi2026/.git/objects/74/b24c6afd1a16409a37eecccbb44c33e3b9220e (stored 0%)
#   adding: ee467wi2026/.git/objects/74/860db78355263bde3f34c8d40ada35b57b9300 (stored 0%)
#   adding: ee467wi2026/.git/objects/74/8cca16e0e3fd706da2686d7863d561a181189a (stored 0%)
#   adding: ee467wi2026/.git/description (deflated 14%)
#   adding: ee467wi2026/.git/packed-refs (deflated 9%)
#   adding: ee467wi2026/.git/COMMIT_EDITMSG (stored 0%)
#   adding: ee467wi2026/lab_2_helpers.py (deflated 62%)
#   adding: ee467wi2026/EE467_Lab_1_Student_Version.ipynb (deflated 75%)
#   adding: ee467wi2026/char-images-31528476/ (stored 0%)
#   adding: ee467wi2026/char-images-31528476/C/ (stored 0%)
#   adding: ee467wi2026/char-images-31528476/C/15.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/C/47.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/C/94.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/C/52.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/C/70.png (deflated 1%)
#   adding: ee467wi2026/char-images-31528476/C/51.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/C/83.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/C/50.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/C/108.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/C/24.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/C/30.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/C/100.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/C/54.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/C/32.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/C/21.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/C/76.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/C/69.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/C/41.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/C
png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/H/60.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/H/96.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/H/46.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/H/107.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/ (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/15.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/122.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/47.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/94.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/52.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/70.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/51.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/83.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/50.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/108.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/24.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/30.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/100.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/54.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/32.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/21.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/76.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/69.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/41.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/81.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/25.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/3.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/34.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/104.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/38.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/4.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/2.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/67.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/10.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/80.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/22.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/66.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/93.png (stored 0%)
#   adding: ee467wi2026/char-images-31528476/B/75.png (stored 0%)
# ...
#   adding: ee467wi2026/captcha-images/3J38.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4NB6.png (stored 0%)
#   adding: ee467wi2026/captcha-images/8CHL.png (stored 0%)
#   adding: ee467wi2026/captcha-images/G8HF.png (stored 0%)
#   adding: ee467wi2026/captcha-images/E3GZ.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2TVS.png (stored 0%)
#   adding: ee467wi2026/captcha-images/7TD9.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4HEX.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4CTC.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2SM9.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2KU3.png (stored 0%)
#   adding: ee467wi2026/captcha-images/5RKH.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4GGX.png (stored 0%)
#   adding: ee467wi2026/captcha-images/B4VJ.png (stored 0%)
#   adding: ee467wi2026/captcha-images/5VA5.png (stored 0%)
#   adding: ee467wi2026/captcha-images/G27D.png (stored 0%)
#   adding: ee467wi2026/captcha-images/K5MR.png (stored 0%)
#   adding: ee467wi2026/captcha-images/G8V3.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2KRC.png (stored 0%)
#   adding: ee467wi2026/captcha-images/G3V9.png (stored 0%)
#   adding: ee467wi2026/captcha-images/N5TR.png (stored 0%)
#   adding: ee467wi2026/captcha-images/6TRN.png (stored 0%)
#   adding: ee467wi2026/captcha-images/D2ME.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2QHA.png (stored 0%)
#   adding: ee467wi2026/captcha-images/E7HY.png (stored 0%)
#   adding: ee467wi2026/captcha-images/M2B3.png (stored 0%)
#   adding: ee467wi2026/captcha-images/5RSW.png (stored 0%)
#   adding: ee467wi2026/captcha-images/9BRX.png (stored 0%)
#   adding: ee467wi2026/captcha-images/8AWH.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2NKG.png (stored 0%)
#   adding: ee467wi2026/captcha-images/N5KM.png (stored 0%)
#   adding: ee467wi2026/captcha-images/7V9B.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2JE3.png (stored 0%)
#   adding: ee467wi2026/captcha-images/C4NN.png (stored 0%)
#   adding: ee467wi2026/captcha-images/L4WS.png (stored 0%)
#   adding: ee467wi2026/captcha-images/C3N5.png (stored 0%)
#   adding: ee467wi2026/captcha-images/B9CX.png (stored 0%)
#   adding: ee467wi2026/captcha-images/J3M9.png (stored 0%)
#   adding: ee467wi2026/captcha-images/3EX8.png (stored 0%)
#   adding: ee467wi2026/captcha-images/K6FP.png (stored 0%)
#   adding: ee467wi2026/captcha-images/6TAM.png (stored 0%)
#   adding: ee467wi2026/captcha-images/B2WF.png (stored 0%)
#   adding: ee467wi2026/captcha-images/E5UE.png (stored 0%)
#   adding: ee467wi2026/captcha-images/8DDZ.png (stored 0%)
#   adding: ee467wi2026/captcha-images/E7KU.png (stored 0%)
#   adding: ee467wi2026/captcha-images/3J8J.png (stored 0%)
#   adding: ee467wi2026/captcha-images/J2QE.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4F5R.png (stored 0%)
#   adding: ee467wi2026/captcha-images/5R6J.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4CQP.png (stored 0%)
#   adding: ee467wi2026/captcha-images/E2DS.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2QCW.png (stored 0%)
#   adding: ee467wi2026/captcha-images/8EJD.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2DFT.png (stored 0%)
#   adding: ee467wi2026/captcha-images/B5UQ.png (stored 0%)
#   adding: ee467wi2026/captcha-images/K3KY.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4L33.png (stored 0%)
#   adding: ee467wi2026/captcha-images/G2Z5.png (stored 0%)
#   adding: ee467wi2026/captcha-images/8BYT.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2QVU.png (stored 0%)
#   adding: ee467wi2026/captcha-images/9AMH.png (stored 0%)
#   adding: ee467wi2026/captcha-images/J7SF.png (stored 0%)
#   adding: ee467wi2026/captcha-images/N3QR.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4L5P.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2M5Y.png (stored 0%)
#   adding: ee467wi2026/captcha-images/5SUH.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4LPR.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2P2M.png (stored 0%)
#   adding: ee467wi2026/captcha-images/J4XZ.png (stored 0%)
#   adding: ee467wi2026/captcha-images/7WTA.png (stored 0%)
#   adding: ee467wi2026/captcha-images/6SM8.png (stored 0%)
#   adding: ee467wi2026/captcha-images/H4YY.png (stored 0%)
#   adding: ee467wi2026/captcha-images/B7JP.png (stored 0%)
#   adding: ee467wi2026/captcha-images/6RZH.png (stored 0%)
#   adding: ee467wi2026/captcha-images/F5MU.png (stored 0%)
#   adding: ee467wi2026/captcha-images/B5WG.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2EH4.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2F3K.png (stored 0%)
#   adding: ee467wi2026/captcha-images/F4MZ.png (stored 0%)
#   adding: ee467wi2026/captcha-images/5V9F.png (stored 0%)
#   adding: ee467wi2026/captcha-images/H8HT.png (stored 0%)
#   adding: ee467wi2026/captcha-images/F3C9.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2P3Z.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2UBN.png (stored 0%)
#   adding: ee467wi2026/captcha-images/M4AM.png (stored 0%)
#   adding: ee467wi2026/captcha-images/H6D7.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4DXU.png (stored 0%)
#   adding: ee467wi2026/captcha-images/K6VW.png (stored 0%)
#   adding: ee467wi2026/captcha-images/J3FS.png (stored 0%)
#   adding: ee467wi2026/captcha-images/G5P5.png (stored 0%)
#   adding: ee467wi2026/captcha-images/7RDD.png (stored 0%)
#   adding: ee467wi2026/captcha-images/9BVF.png (stored 0%)
#   adding: ee467wi2026/captcha-images/H4ZS.png (stored 0%)
#   adding: ee467wi2026/captcha-images/M3AH.png (stored 0%)
#   adding: ee467wi2026/captcha-images/H2QX.png (stored 0%)
#   adding: ee467wi2026/captcha-images/J3NJ.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2DNL.png (stored 0%)
#   adding: ee467wi2026/captcha-images/8CTC.png (stored 0%)
#   adding: ee467wi2026/captcha-images/5W28.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2UZF.png (stored 0%)
#   adding: ee467wi2026/captcha-images/7SDS.png (stored 0%)
#   adding: ee467wi2026/captcha-images/3GYK.png (stored 0%)
#   adding: ee467wi2026/captcha-images/5VXL.png (stored 0%)
#   adding: ee467wi2026/captcha-images/G2LJ.png (stored 0%)
#   adding: ee467wi2026/captcha-images/8DQG.png (stored 0%)
#   adding: ee467wi2026/captcha-images/8DWS.png (stored 0%)
#   adding: ee467wi2026/captcha-images/F6HB.png (stored 0%)
#   adding: ee467wi2026/captcha-images/7X6Z.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2QX5.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2E7F.png (stored 0%)
#   adding: ee467wi2026/captcha-images/H4E3.png (stored 0%)
#   adding: ee467wi2026/captcha-images/C4LM.png (stored 0%)
#   adding: ee467wi2026/captcha-images/7W4S.png (stored 0%)
#   adding: ee467wi2026/captcha-images/K6FM.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2PFS.png (stored 0%)
#   adding: ee467wi2026/captcha-images/9CS9.png (stored 0%)
#   adding: ee467wi2026/captcha-images/D3DW.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2DXK.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2BKT.png (stored 0%)
#   adding: ee467wi2026/captcha-images/5SM2.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4M5A.png (stored 0%)
#   adding: ee467wi2026/captcha-images/L2GD.png (stored 0%)
#   adding: ee467wi2026/captcha-images/E3AY.png (stored 0%)
#   adding: ee467wi2026/captcha-images/E6WK.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2N2V.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2UVL.png (stored 0%)
#   adding: ee467wi2026/captcha-images/3JH9.png (stored 0%)
#   adding: ee467wi2026/captcha-images/G3ZV.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2UFL.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2BLG.png (stored 0%)
#   adding: ee467wi2026/captcha-images/8D6W.png (stored 0%)
#   adding: ee467wi2026/captcha-images/8BNB.png (stored 0%)
#   adding: ee467wi2026/captcha-images/5S8Y.png (stored 0%)
#   adding: ee467wi2026/captcha-images/N5R5.png (stored 0%)
#   adding: ee467wi2026/captcha-images/6TJ3.png (stored 0%)
#   adding: ee467wi2026/captcha-images/E3PL.png (stored 0%)
#   adding: ee467wi2026/captcha-images/G7W4.png (stored 0%)
#   adding: ee467wi2026/captcha-images/C4SU.png (stored 0%)
#   adding: ee467wi2026/captcha-images/3H3F.png (stored 0%)
#   adding: ee467wi2026/captcha-images/E2YR.png (stored 0%)
#   adding: ee467wi2026/captcha-images/L3M8.png (stored 0%)
#   adding: ee467wi2026/captcha-images/M3BR.png (stored 0%)
#   adding: ee467wi2026/captcha-images/8EDJ.png (stored 0%)
#   adding: ee467wi2026/captcha-images/E4N7.png (stored 0%)
#   adding: ee467wi2026/captcha-images/B6RD.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2HYQ.png (stored 0%)
#   adding: ee467wi2026/captcha-images/J6WK.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2PEF.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2E92.png (stored 0%)
#   adding: ee467wi2026/captcha-images/L6F9.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4EET.png (stored 0%)
#   adding: ee467wi2026/captcha-images/6T8C.png (stored 0%)
#   adding: ee467wi2026/captcha-images/6SCY.png (stored 0%)
#   adding: ee467wi2026/captcha-images/E6RY.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2THH.png (stored 0%)
#   adding: ee467wi2026/captcha-images/B7AY.png (stored 0%)
#   adding: ee467wi2026/captcha-images/H5QN.png (stored 0%)
#   adding: ee467wi2026/captcha-images/E7ZC.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2E63.png (stored 0%)
#   adding: ee467wi2026/captcha-images/9AKQ.png (stored 0%)
#   adding: ee467wi2026/captcha-images/F5PE.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4HPN.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4K4G.png (stored 0%)
#   adding: ee467wi2026/captcha-images/6RTW.png (stored 0%)
#   adding: ee467wi2026/captcha-images/6TVY.png (stored 0%)
#   adding: ee467wi2026/captcha-images/B4Z5.png (stored 0%)
#   adding: ee467wi2026/captcha-images/9CQ8.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2H4H.png (stored 0%)
#   adding: ee467wi2026/captcha-images/M6GW.png (stored 0%)
#   adding: ee467wi2026/captcha-images/C4QY.png (stored 0%)
#   adding: ee467wi2026/captcha-images/G7M3.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2DY6.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4G7Z.png (stored 0%)
#   adding: ee467wi2026/captcha-images/E4NY.png (stored 0%)
#   adding: ee467wi2026/captcha-images/G5PU.png (stored 0%)
#   adding: ee467wi2026/captcha-images/K2WR.png (stored 0%)
#   adding: ee467wi2026/captcha-images/E6GM.png (stored 0%)
#   adding: ee467wi2026/captcha-images/J4JF.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2RQ6.png (stored 0%)
#   adding: ee467wi2026/captcha-images/B2PU.png (stored 0%)
#   adding: ee467wi2026/captcha-images/3J9Z.png (stored 0%)
#   adding: ee467wi2026/captcha-images/3DT5.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2FJG.png (stored 0%)
#   adding: ee467wi2026/captcha-images/H2GC.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4KKF.png (stored 0%)
#   adding: ee467wi2026/captcha-images/K6JN.png (stored 0%)
#   adding: ee467wi2026/captcha-images/H6FT.png (stored 0%)
#   adding: ee467wi2026/captcha-images/B4LN.png (stored 0%)
#   adding: ee467wi2026/captcha-images/K3QY.png (stored 0%)
#   adding: ee467wi2026/captcha-images/N6F7.png (stored 0%)
#   adding: ee467wi2026/captcha-images/9CV7.png (stored 0%)
#   adding: ee467wi2026/captcha-images/M3B8.png (stored 0%)
#   adding: ee467wi2026/captcha-images/B4GD.png (stored 0%)
#   adding: ee467wi2026/captcha-images/B4ZJ.png (stored 0%)
#   adding: ee467wi2026/captcha-images/L4M9.png (stored 0%)
#   adding: ee467wi2026/captcha-images/N3FJ.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2QR8.png (stored 0%)
#   adding: ee467wi2026/captcha-images/6TSC.png (stored 0%)
#   adding: ee467wi2026/captcha-images/B2RE.png (stored 0%)
#   adding: ee467wi2026/captcha-images/G7AX.png (stored 0%)
#   adding: ee467wi2026/captcha-images/8BDW.png (stored 0%)
#   adding: ee467wi2026/captcha-images/9DSH.png (stored 0%)
#   adding: ee467wi2026/captcha-images/K5EN.png (stored 0%)
#   adding: ee467wi2026/captcha-images/J2UE.png (stored 0%)
#   adding: ee467wi2026/captcha-images/F4DR.png (stored 0%)
#   adding: ee467wi2026/captcha-images/B4R8.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4JS9.png (stored 0%)
#   adding: ee467wi2026/captcha-images/G4NA.png (stored 0%)
#   adding: ee467wi2026/captcha-images/8D4E.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4GYN.png (stored 0%)
#   adding: ee467wi2026/captcha-images/J8NE.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2NTM.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4FS8.png (stored 0%)
#   adding: ee467wi2026/captcha-images/E4DK.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2P3L.png (stored 0%)
#   adding: ee467wi2026/captcha-images/7QW2.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2HLR.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2LVH.png (stored 0%)
#   adding: ee467wi2026/captcha-images/D2US.png (stored 0%)
#   adding: ee467wi2026/captcha-images/E6JX.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4P2D.png (stored 0%)
#   adding: ee467wi2026/captcha-images/H5CR.png (stored 0%)
#   adding: ee467wi2026/captcha-images/3HHL.png (stored 0%)
#   adding: ee467wi2026/captcha-images/3FZN.png (stored 0%)
#   adding: ee467wi2026/captcha-images/6R67.png (stored 0%)
#   adding: ee467wi2026/captcha-images/F2LH.png (stored 0%)
#   adding: ee467wi2026/captcha-images/6T2V.png (stored 0%)
#   adding: ee467wi2026/captcha-images/3CD5.png (stored 0%)
#   adding: ee467wi2026/captcha-images/C2PW.png (stored 0%)
#   adding: ee467wi2026/captcha-images/C4Q4.png (stored 0%)
#   adding: ee467wi2026/captcha-images/B3BA.png (stored 0%)
#   adding: ee467wi2026/captcha-images/6QMC.png (stored 0%)
#   adding: ee467wi2026/captcha-images/9BXX.png (stored 0%)
#   adding: ee467wi2026/captcha-images/N2PL.png (stored 0%)
#   adding: ee467wi2026/captcha-images/3JHS.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2QZE.png (stored 0%)
#   adding: ee467wi2026/captcha-images/G9ZE.png (stored 0%)
#   adding: ee467wi2026/captcha-images/L2ZJ.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4C92.png (stored 0%)
#   adding: ee467wi2026/captcha-images/3CZ5.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2DHJ.png (stored 0%)
#   adding: ee467wi2026/captcha-images/5TTS.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4G5T.png (stored 0%)
#   adding: ee467wi2026/captcha-images/F4NL.png (stored 0%)
#   adding: ee467wi2026/captcha-images/B6ZA.png (stored 0%)
#   adding: ee467wi2026/captcha-images/B7E5.png (stored 0%)
#   adding: ee467wi2026/captcha-images/7VYD.png (stored 0%)
#   adding: ee467wi2026/captcha-images/M4ZP.png (stored 0%)
#   adding: ee467wi2026/captcha-images/K3MB.png (stored 0%)
#   adding: ee467wi2026/captcha-images/8E28.png (stored 0%)
#   adding: ee467wi2026/captcha-images/9ATZ.png (stored 0%)
#   adding: ee467wi2026/captcha-images/J2FP.png (stored 0%)
#   adding: ee467wi2026/captcha-images/K2NU.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4K3F.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4JMJ.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2N29.png (stored 0%)
#   adding: ee467wi2026/captcha-images/5VBJ.png (stored 0%)
#   adding: ee467wi2026/captcha-images/L3ZZ.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4EL3.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2JA5.png (stored 0%)
#   adding: ee467wi2026/captcha-images/C3X6.png (stored 0%)
#   adding: ee467wi2026/captcha-images/6RCE.png (stored 0%)
#   adding: ee467wi2026/captcha-images/5SXQ.png (stored 0%)
#   adding: ee467wi2026/captcha-images/B7J9.png (stored 0%)
#   adding: ee467wi2026/captcha-images/3CJF.png (stored 0%)
#   adding: ee467wi2026/captcha-images/F4MN.png (stored 0%)
#   adding: ee467wi2026/captcha-images/4GEV.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2HDR.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2JBV.png (stored 0%)
#   adding: ee467wi2026/captcha-images/J7AM.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2U5L.png (stored 0%)
#   adding: ee467wi2026/captcha-images/N3NY.png (stored 0%)
#   adding: ee467wi2026/captcha-images/2K8R.png (stored 0%)
#   adding: ee467wi2026/captcha-images/7UH6.png (stored 0%)
#   adding: ee467wi2026/captcha-model.weights.h5 (deflated 16%)

# %% [markdown]
# ### Open-Ended Extension:
#
# TensorFlow is one popular framework for implementing Deep Neural Networks, and another widely used framework is **PyTorch**. After you successfully complete this lab:
#
# - Use your favorite language model and/or coding assistant (e.g., **GPT**, **Copilot**, **Gemini**, **Cursor**, etc.) to **convert your TensorFlow CNN implementation into PyTorch**.
# - Repeat the same training + evaluation experiments in PyTorch.
# - You should observe **similar results** (minor differences are expected due to randomness and implementation details).
#
# ✅ **Submission Requirement:**
# Include this as a **separate notebook** in your lab-submission GitHub repository named:
#
# **`Breaking-CAPTCHAS-Pytorch.ipynb`**

# %% [markdown]
# ## References
# 1. How to break a CAPTCHA system in 15 minutes with Machine Learning: https://medium.com/@ageitgey/how-to-break-a-captcha-system-in-15-minutes-with-machine-learning-dbebb035a710
# 2. CaptchaSolver Jupyter Notebook: https://github.com/BenjaminWegener/CaptchaSolver
# 3. Keras Tutorial: The Ultimate Beginner's Guide to Deep Learning in Python: https://elitedatascience.com/keras-tutorial-deep-learning-in-python
# 4. Keras API reference: https://keras.io/
# 5. Tensorflow API reference: https://www.tensorflow.org/api_docs
